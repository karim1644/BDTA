# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %% [markdown]
# ## Ex 1

# %%
df = pd.read_csv('../data/bank.csv', sep=',')
df

# %%
print("Righe:", df.shape[0])
print("Colonne:", df.shape[1])

# %%
df.isnull().sum().sum()

# %%
# contare i valori della colonna target (label)

# %% [markdown]
# ## Ex 2

# %%
df['Gender'] = df['Gender'].map({"Female": 0, "Male": 1})

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France       0   42
# 1             2    15647311       Hill          608     Spain       0   41
# 2             3    15619304       Onio          502    France       0   42
# 3             4    15701354       Boni          699    France       0   39
# 4             5    15737888   Mitchell          850     Spain       0   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France       1   39
# 9996       9997    15569892  Johnstone          516    France       1   35
# 9997       9998    15584532        Liu          709    France       0   36
# 9998       9999    15682355  Sabbatini          772   Germany       1   42
# 9999      10000    15628319     Walker          792    France       0   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## Ex 3

# %% [markdown]
# ## Ex 4

# %% [markdown]
# Le prime tre colonne vanno eliminate perché non servono al fine della predizione. Il modello non va allenato su quelle colonne, perché se no imparerebbe per esempio che l'utente con l'id 1573788 è uno che non lascia una banca. Stessa cosa per la RowNumber e il Surname.

# %% [markdown]
# ## Ex 5

# %% [markdown]
# ## Ex 6
